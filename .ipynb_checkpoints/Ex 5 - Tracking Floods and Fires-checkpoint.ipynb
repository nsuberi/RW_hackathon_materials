# %%
# Data fetching library
import requests as req
# used below: 'res' stands for 'response'

# Data manipulation libraries
import pandas as pd
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 1000

# Data visualization libraries
import folium

# %% [markdown]
# # Find information about all data on the Resource Watch API, format as DataFrame

# %%
# Base URL for getting dataset metadata from RW API
# Metadata = Data that describes Data 
url = "https://api.resourcewatch.org/v1/dataset?sort=slug,-provider,userId&status=saved&includes=metadata,vocabulary,widget,layer"

# page[size] tells the API the maximum number of results to send back
# There are currently between 200 and 300 datasets on the RW API
payload = { "application":"rw", "page[size]": 1000}

# Request all datasets, and extract the data from the response
res = req.get(url, params=payload)
data = res.json()["data"]

#############################################################

### Convert the json object returned by the API into a pandas DataFrame
# Another option: https://pandas.pydata.org/pandas-docs/stable/generated/pandas.io.json.json_normalize.html
datasets_on_api = {}
for ix, dset in enumerate(data):
    atts = dset["attributes"]
    metadata = atts["metadata"]
    layers = atts["layer"]
    widgets = atts["widget"]
    tags = atts["vocabulary"]
    datasets_on_api[atts["name"]] = {
        "rw_id":dset["id"],
        "table_name":atts["tableName"],
        "provider":atts["provider"],
        "date_updated":atts["updatedAt"],
        "num_metadata":len(metadata),
        "metadata": metadata,
        "num_layers":len(layers),
        "layers": layers,
        "num_widgets":len(widgets),
        "widgets": widgets,
        "num_tags":len(tags),
        "tags":tags
    }

# Create the DataFrame, name the index, and sort by date_updated
# More recently updated datasets at the top
current_datasets_on_api = pd.DataFrame.from_dict(datasets_on_api, orient='index')
current_datasets_on_api.index.rename("Dataset", inplace=True)
current_datasets_on_api.sort_values(by=["date_updated"], inplace=True, ascending = False)

# %%
# Simple search:
search_terms = ["flood", "fire"]
# View datasets on the Resource Watch API
dataset_matches = [name for name in current_datasets_on_api.index if any(term in name.lower() for term in search_terms)]

dataset_matches
# Out:
# ['Flood Risk',
#  'VIIRS Active Fire -- Global',
#  'Groundwater Vulnerability to Floods and Droughts',
#  'Floods News Reports',
#  'Floods by magnitude',
#  'MODIS Active Fires',
#  'Current Floods']

# %%
disaster_data = current_datasets_on_api.loc[dataset_matches]
disaster_data
# Out:
#                                                                                  rw_id  \
# Dataset
# Flood Risk                                        01ddff59-8cbc-4420-8c0d-9d8317a63292
# VIIRS Active Fire -- Global                       20cc5eca-8c63-4c41-8e8e-134dcf1e6d76
# Groundwater Vulnerability to Floods and Droughts  c8d3a605-3d50-46cf-a707-2aacbf6f7cb0
# Floods News Reports                               63e29bc8-c341-44a4-bc0e-1d3dc1714c13
# Floods by magnitude                               a972a30d-f766-4d68-a85d-392538b4ccf9
# MODIS Active Fires                                a9e33aad-eece-4453-8279-31c4b4e0583f
# Current Floods                                    bbfcf170-5c47-40b0-880d-b04648eba354
#
#                                                                                          table_name  \
# Dataset
# Flood Risk                                        aqueduct_global_flood_risk_data_by_country_201...
# VIIRS Active Fire -- Global                                               vnp14imgtdl_nrt_global_7d
# Groundwater Vulnerability to Floods and Droughts  wat_022_global_groundwater_vulnerability_flood...
# Floods News Reports                                                               flood_observatory
# Floods by magnitude                                                               flood_observatory
# MODIS Active Fires                                                               modis_c6_global_7d
# Current Floods                                                                     table_6862998136
#
#                                                  provider  \
# Dataset
# Flood Risk                                        cartodb
# VIIRS Active Fire -- Global                       cartodb
# Groundwater Vulnerability to Floods and Droughts  cartodb
# Floods News Reports                               cartodb
# Floods by magnitude                               cartodb
# MODIS Active Fires                                cartodb
# Current Floods                                    cartodb
#
#                                                               date_updated  \
# Dataset
# Flood Risk                                        2017-09-12T15:25:35.303Z
# VIIRS Active Fire -- Global                       2017-09-08T20:51:08.634Z
# Groundwater Vulnerability to Floods and Droughts  2017-08-17T18:54:07.514Z
# Floods News Reports                               2017-08-15T10:24:12.158Z
# Floods by magnitude                               2017-08-15T10:21:45.096Z
# MODIS Active Fires                                2017-08-15T10:19:50.057Z
# Current Floods                                    2017-07-18T13:34:11.955Z
#
#                                                   num_metadata  \
# Dataset
# Flood Risk                                                   1
# VIIRS Active Fire -- Global                                  1
# Groundwater Vulnerability to Floods and Droughts             1
# Floods News Reports                                          0
# Floods by magnitude                                          0
# MODIS Active Fires                                           0
# Current Floods                                               1
#
#                                                                                            metadata  \
# Dataset
# Flood Risk                                        [{'id': '59a427acce86740012fcb23d', 'type': 'm...
# VIIRS Active Fire -- Global                       [{'id': '59a426707b6c000012baa6f7', 'type': 'm...
# Groundwater Vulnerability to Floods and Droughts  [{'id': '59a427abce86740012fcb23b', 'type': 'm...
# Floods News Reports                                                                              []
# Floods by magnitude                                                                              []
# MODIS Active Fires                                                                               []
# Current Floods                                    [{'id': '59a424c27b6c000012baa6f6', 'type': 'm...
#
#                                                   num_layers  \
# Dataset
# Flood Risk                                                 1
# VIIRS Active Fire -- Global                                3
# Groundwater Vulnerability to Floods and Droughts           1
# Floods News Reports                                        3
# Floods by magnitude                                        1
# MODIS Active Fires                                         1
# Current Floods                                             2
#
#                                                                                              layers  \
# Dataset
# Flood Risk                                        [{'id': 'fbdb2177-cb91-4d21-b345-59037e276752'...
# VIIRS Active Fire -- Global                       [{'id': 'bf4646d0-1e09-4dab-a8e8-36a844983ade'...
# Groundwater Vulnerability to Floods and Droughts  [{'id': '70fdf0b1-2529-4b1e-bce9-814417cdfcb8'...
# Floods News Reports                               [{'id': 'd0e35d92-3669-4bc2-b5d6-58b456fbf847'...
# Floods by magnitude                               [{'id': 'efe2fcae-a9c3-4ec6-8004-4029e48cf2a8'...
# MODIS Active Fires                                [{'id': 'f3ee5110-083d-4a94-8b5d-af087d2b18aa'...
# Current Floods                                    [{'id': '763e9347-73f1-48bc-8070-48d4de253412'...
#
#                                                   num_widgets  \
# Dataset
# Flood Risk                                                  1
# VIIRS Active Fire -- Global                                 3
# Groundwater Vulnerability to Floods and Droughts            0
# Floods News Reports                                         0
# Floods by magnitude                                         0
# MODIS Active Fires                                          0
# Current Floods                                              2
#
#                                                                                             widgets  \
# Dataset
# Flood Risk                                        [{'id': '7cdad4dc-0074-4bd4-b3bd-db6ffc4e0180'...
# VIIRS Active Fire -- Global                       [{'id': '5ebeddda-8f3d-4e63-8a52-08e15c3e148c'...
# Groundwater Vulnerability to Floods and Droughts                                                 []
# Floods News Reports                                                                              []
# Floods by magnitude                                                                              []
# MODIS Active Fires                                                                               []
# Current Floods                                    [{'id': '14a08a36-e9c7-4f3a-aeb1-f3e411c94a68'...
#
#                                                   num_tags  \
# Dataset
# Flood Risk                                               1
# VIIRS Active Fire -- Global                              1
# Groundwater Vulnerability to Floods and Droughts         1
# Floods News Reports                                      1
# Floods by magnitude                                      1
# MODIS Active Fires                                       1
# Current Floods                                           1
#
#                                                                                                tags
# Dataset
# Flood Risk                                        [{'type': 'vocabulary', 'attributes': {'resour...
# VIIRS Active Fire -- Global                       [{'type': 'vocabulary', 'attributes': {'resour...
# Groundwater Vulnerability to Floods and Droughts  [{'type': 'vocabulary', 'attributes': {'resour...
# Floods News Reports                               [{'type': 'vocabulary', 'attributes': {'resour...
# Floods by magnitude                               [{'type': 'vocabulary', 'attributes': {'resour...
# MODIS Active Fires                                [{'type': 'vocabulary', 'attributes': {'resour...
# Current Floods                                    [{'type': 'vocabulary', 'attributes': {'resour...

# %% [markdown]
# # Floods

# %%
disaster_data.loc["Floods News Reports", "layers"]
# Out:
# [{'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': '63e29bc8-c341-44a4-bc0e-1d3dc1714c13',
#    'default': False,
#    'description': '',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': ['global'],
#    'layerConfig': {'account': 'insights',
#     'body': {'layers': [{'options': {'cartocss': '#flood_observatory{  marker-fill-opacity: 0.8;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-width: 10;  marker-fill: #EDF8B1;  marker-allow-overlap: true;}#flood_observatory [ severity <= 2] {   marker-fill: #2C7FB8;}#flood_observatory [ severity <= 1.75] {   marker-fill: #7FCDBB;}#flood_observatory [ severity <= 1.25] {   marker-fill: #EDF8B1;}',
#         'cartocss_version': '2.3.0',
#         'sql': "SELECT st_transform(the_geom_webmercator,32663) as the_geom_webmercator FROM flood_observatory where to_date(date_began, 'DD-Mon-YY') > (CURRENT_DATE - interval '3 month')"},
#        'type': 'mapnik'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#2C7FB8', 'name': 'Severity <= 2'},
#      {'color': '#7FCDBB', 'name': 'Severity <= 1.75'},
#      {'color': '#EDF8B1', 'name': 'Severity <= 1.25'}],
#     'type': 'basic'},
#    'name': 'Global Flood Detection System (JRC, Dartmouth Flood Observatory) (pulse)',
#    'provider': 'cartodb',
#    'slug': 'global-flood-detection-system-jrc-dartmouth-flood-observatory-pulse',
#    'staticImageConfig': {'bbox': [-110, -65, 110, 65],
#     'format': 'png',
#     'height': 1024,
#     'srs': None,
#     'urlTemplate': 'https://{{account}}.carto.com/api/v1/map/static/bbox/{{token_groupid}}/{{bbox}}/{{width}}/{{height}}.{{format}}',
#     'width': 2048},
#    'userId': '57a0aa1071e394dd32ffe137'},
#   'id': 'd0e35d92-3669-4bc2-b5d6-58b456fbf847',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {'config one': {'from': {'data': 'table'},
#      'type': 'lorem'}},
#    'dataset': '63e29bc8-c341-44a4-bc0e-1d3dc1714c13',
#    'default': True,
#    'description': 'Floods News Reports',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [],
#    'layerConfig': {'account': 'insights',
#     'body': {'layers': [{'options': {'cartocss': '#flood_observatory{marker-fill-opacity: 1;marker-line-color: #FFFFFF;marker-line-width: 1;marker-line-opacity: 0.5;marker-placement: point;marker-type: ellipse;marker-width: 5;marker-fill: #3bb2d0;marker-allow-overlap: true;}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM flood_observatory'},
#        'type': 'mapnik'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#3bb2d0',
#       'name': 'Floods News Reports'}],
#     'type': 'basic'},
#    'name': 'Floods News Reports',
#    'provider': 'cartodb',
#    'slug': 'floods-news-report',
#    'staticImageConfig': {'bbox': [-110, -65, 110, 65],
#     'format': 'png',
#     'height': 1024,
#     'srs': None,
#     'urlTemplate': 'https://{{account}}.carto.com/api/v1/map/static/bbox/{{token_groupid}}/{{bbox}}/{{width}}/{{height}}.{{format}}',
#     'width': 2048},
#    'userId': '58333dcfd9f39b189ca44c75'},
#   'id': '55fce6b6-cd58-40d4-8abe-cca92bbd542d',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': '63e29bc8-c341-44a4-bc0e-1d3dc1714c13',
#    'default': False,
#    'description': 'Floods News Reports',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [],
#    'layerConfig': {'account': 'insights',
#     'body': {'layers': [{'options': {'cartocss': '#flood_observatory{marker-fill-opacity: 0.9;marker-line-color: #05203c;marker-line-width: 1;marker-line-opacity: 1;marker-placement: point;marker-type: ellipse;marker-width: 10;marker-fill: #4a81b9;marker-allow-overlap: true;}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT ST_Transform(the_geom_webmercator, 32663) as the_geom_webmercator FROM flood_observatory'},
#        'type': 'mapnik'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#4a81b9',
#       'name': 'Floods News Reports'}],
#     'type': 'basic'},
#    'name': 'Floods News Reports (pulse)',
#    'provider': 'cartodb',
#    'slug': 'floods-news-reports',
#    'staticImageConfig': {'bbox': [-110, -65, 110, 65],
#     'format': 'png',
#     'height': 1024,
#     'srs': None,
#     'urlTemplate': 'https://{{account}}.carto.com/api/v1/map/static/bbox/{{token_groupid}}/{{bbox}}/{{width}}/{{height}}.{{format}}',
#     'width': 2048},
#    'userId': '5858f37140621f11066fb2f7'},
#   'id': 'd936031f-51fa-45d8-b945-b52175106fc3',
#   'type': 'layer'}]

# %%
rw_id = "63e29bc8-c341-44a4-bc0e-1d3dc1714c13"
table_name = "flood_observatory"
sql = "SELECT st_x(the_geom) as lon, st_y(the_geom) as lat FROM flood_observatory where to_date(date_began, 'DD-Mon-YY') > (CURRENT_DATE - interval '3 month')"
#sql_explore = "Select * from flood_observatory LIMIT 1"

query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

#query = query_base.format(rw_id, sql_explore)
query = query_base.format(rw_id, sql)

res = req.get(query)

flood_data = res.json()["data"]

# %%
flood_data
# Out:
# [{'lat': 34.2375, 'lon': -111.62},
#  {'lat': 22.3851, 'lon': 114.139},
#  {'lat': 39.1877, 'lon': -94.646},
#  {'lat': 54.3667, 'lon': -7.7468},
#  {'lat': 2.72692, 'lon': 33.0057},
#  {'lat': 9.42341, 'lon': 29.6159},
#  {'lat': 30.1135, 'lon': -95.3388},
#  {'lat': 27.9409, 'lon': 83.8784},
#  {'lat': 24.5912, 'lon': 90.0148},
#  {'lat': 28.1657, 'lon': 79.076},
#  {'lat': 8.40278, 'lon': -12.2501},
#  {'lat': 21.4878, 'lon': -99.5452},
#  {'lat': -44.1524, 'lon': 170.978},
#  {'lat': 52.9946, 'lon': 9.92006},
#  {'lat': 47.8978, 'lon': 136.879},
#  {'lat': 35.4339, 'lon': 74.0057},
#  {'lat': 21.6577, 'lon': 105.158},
#  {'lat': 22.9061, 'lon': 88.0848},
#  {'lat': 21.898, 'lon': 70.9375},
#  {'lat': 39.0201, 'lon': 140.417},
#  {'lat': 22.6775, 'lon': 98.9472},
#  {'lat': 7.83511, 'lon': -67.5271},
#  {'lat': 38.4883, 'lon': -84.2042},
#  {'lat': 10.079, 'lon': 7.19827},
#  {'lat': 27.295, 'lon': 86.427},
#  {'lat': 33.4014, 'lon': 72.3232},
#  {'lat': 25.9426, 'lon': 112.853}]

# %%
m = folium.Map(location=[0, 0], zoom_start=1, tiles='OpenStreetMap')
for point in flood_data:
    folium.Marker(location=[point["lat"], point["lon"]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Fires

# %%
disaster_data.loc["VIIRS Active Fire -- Global", "layers"]
# Out:
# [{'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': '20cc5eca-8c63-4c41-8e8e-134dcf1e6d76',
#    'default': True,
#    'description': '',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [],
#    'layerConfig': {'account': 'wri-01',
#     'body': {'layers': [{'options': {'cartocss': '#vnp14imgtdl_nrt_global_7d{  marker-fill-opacity: 1;  marker-line-color: #FFF;  marker-line-width: 0;  marker-line-opacity: 1;  marker-width: 5;  marker-fill: #B10026;  marker-allow-overlap: true;} #vnp14imgtdl_nrt_global_7d [ frp >= 0] {   marker-fill: #B10026;marker-fill-opacity: 0.1;} #vnp14imgtdl_nrt_global_7d [ frp >= 30] {   marker-fill: #E31A1C;marker-fill-opacity: 0.2;} #vnp14imgtdl_nrt_global_7d [ frp >= 50] {   marker-fill: #FC4E2A;marker-fill-opacity: 0.3;} #vnp14imgtdl_nrt_global_7d [ frp >= 75] {   marker-fill: #FD8D3C;marker-fill-opacity: 0.4;} #vnp14imgtdl_nrt_global_7d [ frp >= 100] {   marker-fill: #FEB24C;marker-fill-opacity: 0.7;} #vnp14imgtdl_nrt_global_7d [ frp >= 500] {   marker-fill: #FED976;marker-fill-opacity: 1; } #vnp14imgtdl_nrt_global_7d [ frp >= 1000] {   marker-fill: #FFFFB2;marker-fill-opacity: 1; }',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM vnp14imgtdl_nrt_global_7d'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#B10026',
#       'marker-fill-opacity': 0.5,
#       'value': '>0 MW'},
#      {'color': '#E31A1C', 'value': '>30 MW'},
#      {'color': '#FC4E2A', 'value': '>50 MW'},
#      {'color': '#FD8D3C', 'value': '>75 MW'},
#      {'color': '#FEB24C', 'value': '>100 MW'},
#      {'color': '#FED976', 'value': '>500 MW'},
#      {'color': '#FFFFB2', 'value': '>1000 MW'}],
#     'type': 'choropleth',
#     'unit': 'MW'},
#    'name': 'Test_layer_viirs',
#    'provider': 'cartodb',
#    'slug': 'test_layer_viirs',
#    'staticImageConfig': {},
#    'userId': '58fde4354eecd9073107af0f'},
#   'id': 'bf4646d0-1e09-4dab-a8e8-36a844983ade',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': '20cc5eca-8c63-4c41-8e8e-134dcf1e6d76',
#    'default': False,
#    'description': '',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': [''],
#    'layerConfig': {'account': 'wri-01',
#     'body': {'layers': [{'options': {'cartocss': '#vnp14imgtdl_nrt_global_7d{  [bright_ti5 >= 0] {marker-file: url(http://com.cartodb.users-assets.production.s3.amazonaws.com/maki-icons/square-18.svg);  marker-fill-opacity: 0.9;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-placement: point;  marker-type: ellipse;  marker-width: 10;  marker-fill: #B10026;  marker-allow-overlap: true;}  [bright_ti5 >= 100] {marker-file: url(http://com.cartodb.users-assets.production.s3.amazonaws.com/maki-icons/square-18.svg);  marker-fill-opacity: 0.9;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-placement: point;  marker-type: ellipse;  marker-width: 10;  marker-fill: #E31A1C;  marker-allow-overlap: true;}  [bright_ti5 >= 200] {marker-file: url(http://com.cartodb.users-assets.production.s3.amazonaws.com/maki-icons/square-18.svg);  marker-fill-opacity: 0.9;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-placement: point;  marker-type: ellipse;  marker-width: 10;  marker-fill: #FC4E2A;  marker-allow-overlap: true;}  [bright_ti5 >= 295.7] {marker-file: url(http://com.cartodb.users-assets.production.s3.amazonaws.com/maki-icons/square-18.svg);  marker-fill-opacity: 0.9;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-placement: point;  marker-type: ellipse;  marker-width: 10;  marker-fill: #FD8D3C;  marker-allow-overlap: true;}      [bright_ti5 >= 380] {marker-file: url(http://com.cartodb.users-assets.production.s3.amazonaws.com/maki-icons/square-18.svg);  marker-fill-opacity: 0.9;  marker-line-color: #FFF;  marker-line-width: 1;  marker-line-opacity: 1;  marker-placement: point;  marker-type: ellipse;  marker-width: 10;  marker-fill: #f9be6f;  marker-allow-overlap: true;}}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT * FROM vnp14imgtdl_nrt_global_7d'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#B10026', 'name': 'Bright TI5 >= 0'},
#      {'color': '#E31A1C', 'name': 'Bright TI5 >= 100'},
#      {'color': '#FC4E2A', 'name': 'Bright TI5 >= 200'},
#      {'color': '#FD8D3C', 'name': 'Bright TI5 >= 295.7'},
#      {'color': '#f9be6f', 'name': 'Bright TI5 >= 380'}],
#     'type': 'basic'},
#    'name': 'VIIRS Active Fire -- Global',
#    'provider': 'cartodb',
#    'slug': 'viirs-active-fire-global',
#    'staticImageConfig': {},
#    'userId': '58fde4354eecd9073107af0f'},
#   'id': '5ca12eec-f8fe-49eb-b353-67c9eeb5bc6a',
#   'type': 'layer'},
#  {'attributes': {'application': ['rw'],
#    'applicationConfig': {},
#    'dataset': '20cc5eca-8c63-4c41-8e8e-134dcf1e6d76',
#    'default': False,
#    'description': 'Current Fires',
#    'env': 'production',
#    'interactionConfig': {},
#    'iso': ['global'],
#    'layerConfig': {'account': 'wri-01',
#     'body': {'layers': [{'options': {'cartocss': '#vnp14imgtdl_nrt_global_7d{  marker-fill-opacity: 1;  marker-line-color: #FFF;  marker-line-width: 0;  marker-line-opacity: 1;  marker-width: 5;  marker-fill: #FFFFB2;  marker-allow-overlap: true;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 380] {   marker-fill: #B10026;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 351.3] {   marker-fill: #E31A1C;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 332.5] {   marker-fill: #FC4E2A;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 314.1] {   marker-fill: #FD8D3C;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 295.7] {   marker-fill: #FEB24C;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 277.3] {   marker-fill: #FED976;} #vnp14imgtdl_nrt_global_7d [ bright_ti5 <= 258.9] {   marker-fill: #FFFFB2;}',
#         'cartocss_version': '2.3.0',
#         'sql': 'SELECT st_transform(the_geom_webmercator,32663) as the_geom_webmercator, bright_ti5 FROM vnp14imgtdl_nrt_global_7d'},
#        'type': 'cartodb'}],
#      'maxzoom': 18,
#      'minzoom': 3}},
#    'legendConfig': {'items': [{'color': '#B10026',
#       'name': 'Bright TI5 <= 380'},
#      {'color': '#E31A1C', 'name': 'Bright TI5 <= 351.3'},
#      {'color': '#FC4E2A', 'name': 'Bright TI5 <= 332.5'},
#      {'color': '#FD8D3C', 'name': 'Bright TI5 <= 314.1'},
#      {'color': '#FEB24C', 'name': 'Bright TI5 <= 295.7'},
#      {'color': '#FED976', 'name': 'Bright TI5 <= 277.3'},
#      {'color': '#FFFFB2', 'name': 'Bright TI5 <= 258.9'}],
#     'type': 'basic'},
#    'name': 'VIIRS Active Fires(Visible Infrared Imaging Radiometer Suite) (pulse)',
#    'provider': 'cartodb',
#    'slug': 'viirs-active-fires-visible-infrared-imaging-radiometer-suite-nasa-noaa',
#    'staticImageConfig': {'bbox': [-110, -65, 110, 65],
#     'format': 'png',
#     'height': 1024,
#     'srs': None,
#     'urlTemplate': 'https://{{account}}.carto.com/api/v1/map/static/bbox/{{token_groupid}}/{{bbox}}/{{width}}/{{height}}.{{format}}',
#     'width': 2048},
#    'userId': '58fde4354eecd9073107af0f'},
#   'id': '22c9c1bc-fc40-4c85-ae70-a7c837c126f2',
#   'type': 'layer'}]

# %%
rw_id = "20cc5eca-8c63-4c41-8e8e-134dcf1e6d76"
table_name = "vnp14imgtdl_nrt_global_7d"
sql_explore = "SELECT * FROM vnp14imgtdl_nrt_global_7d LIMIT 1"

# where to_date(acq_date, 'yyyy-mm-dd\"T\"hh24:mi:ss\"Z\"') > (CURRENT_DATE - interval '3 month')
### NEED TO FIGURE OUT HOW TO WORK THIS DATE CONVERSION

sql = "SELECT st_x(the_geom) as lon, st_y(the_geom) as lat FROM vnp14imgtdl_nrt_global_7d LIMIT 1000"
#sql.format(date_handler)
query_base = "https://api.resourcewatch.org/v1/query/{}?sql={}"

#query = query_base.format(rw_id, sql_explore)
query = query_base.format(rw_id, sql)

res = req.get(query)

fire_data = res.json()["data"]

# %%
fire_data[0:10]
# Out:
# [{'lat': -23.68104, 'lon': 146.86627},
#  {'lat': -15.4707, 'lon': 142.02798},
#  {'lat': 44.76628, 'lon': 77.56821},
#  {'lat': 45.86715, 'lon': 41.51502},
#  {'lat': 51.09018, 'lon': 59.58368},
#  {'lat': 31.65545, 'lon': 47.51468},
#  {'lat': -17.88512, 'lon': 33.62486},
#  {'lat': -17.93925, 'lon': 23.11303},
#  {'lat': -12.6693, 'lon': 20.12878},
#  {'lat': -11.1742, 'lon': 31.03356}]

# %%
m = folium.Map(location=[0, 0], zoom_start=1, tiles='OpenStreetMap')
for point in fire_data:
    folium.Marker(location=[point["lat"], point["lon"]]).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
